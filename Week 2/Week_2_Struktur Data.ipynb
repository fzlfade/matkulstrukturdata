# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

print(n1.dataval)
print(n2.dataval)
print(n3.dataval)
# Out:
# Januari
# Februari
# Maret

# %%
class LinkedList:
    def __init__(self):
        self.headval = None

Li = LinkedList()
Li.headval = n1

# Link first Node to second node
Li.headval.nextval = n2

# Link second Node to third node
n2.nextval = n3

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

class LinkedList:
    def __init__(self):
        self.headval = None

    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

Li = LinkedList()
Li.headval = n1

# Link first Node to second node
Li.headval.nextval = n2

# Link second Node to third node
n2.nextval = n3

Li.listprint()
# Out:
# Januari
# Februari
# Maret

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

#create Node
n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

class LinkedList:
    def __init__(self):
        self.headval = None

#Print the linked list
    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

#Create atrribute add beginning to update the new nodes next val to existing node
    def AddBeginning(self, newdata):
        NewNode = Node(newdata)
        NewNode.nextval = self.headval
        self.headval = NewNode

Li = LinkedList()
Li.headval = n1

# Link first Node to second node
Li.headval.nextval = n2

# Link second Node to third node
n2.nextval = n3

Li.AddBeginning("Start")
Li.listprint()
# Out:
# Start
# Januari
# Februari
# Maret

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

#create Node
n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

class LinkedList:
    def __init__(self):
        self.headval = None

#Print the linked list
    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

#Add node in middle
    def AddinBetween(self, mid_node, newdata):
        if mid_node is None:
            print("The mentioned node is absent")
            return
        NewNode = Node(newdata)
        NewNode.nextval = mid_node.nextval
        mid_node.nextval = NewNode

Li = LinkedList()
Li.headval = n1

# Link first Node to second node
Li.headval.nextval = n2

# Link second Node to third node
n2.nextval = n3

Li.AddinBetween(n1, "Middle")
Li.listprint()
# Out:
# Januari
# Middle
# Februari
# Maret

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

#create Node
n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

class LinkedList:
    def __init__(self):
        self.headval = None

#Print the linked list
    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

#Add node in the end
    def AddinEnd(self, newdata):
        NewNode = Node(newdata)
        if self.headval is None:
            self.headval = NewNode
            return
        last = self.headval
        while(last.nextval):
            last = last.nextval
        last.nextval=NewNode

Li = LinkedList()
Li.headval = n1

# Link first Node to second node
Li.headval.nextval = n2

# Link second Node to third node
n2.nextval = n3

Li.AddinEnd("Last")
Li.listprint()
# Out:
# Januari
# Februari
# Maret
# Last

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None
 
class LinkedList:
    def __init__(self):
        self.headval = None

#Print the linked list
    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

#Add node in the beginning
    def AddBeginning(self, newdata):
        NewNode = Node(newdata)
        NewNode.nextval = self.headval
        self.headval = NewNode

#Remove node by key
    def RemoveNode(self, Removekey):
        HeadVal = self.headval
        if (HeadVal is not None):
            if (HeadVal.dataval == Removekey):
                self.headval = HeadVal.nextval
                HeadVal = None
                return
        while (HeadVal is not None):
            if HeadVal.dataval == Removekey:
                break
            prev = HeadVal
            HeadVal = HeadVal.nextval
        if (HeadVal == None):
            return
        prev.nextval = HeadVal.nextval
        HeadVal = None

Li = LinkedList()

#Add Node
Li.AddBeginning("Juni")
Li.AddBeginning("Mei")
Li.AddBeginning("April")
print("List before removal")
Li.listprint()
print("=====================================================================")
Li.RemoveNode("Mei")
print("List after removal")
Li.listprint()
# Out:
# List before removal
# April
# Mei
# Juni
# =====================================================================
# List after removal
# April
# Juni

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None
 
class LinkedList:
    def __init__(self):
        self.headval = None

#Print the linked list
    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

#Add node in the beginning
    def AddBeginning(self, newdata):
        NewNode = Node(newdata)
        NewNode.nextval = self.headval
        self.headval = NewNode

#Remove first node
    def RemoveFirst(self):
        afterhead = self.headval
        self.headval = afterhead.nextval

Li = LinkedList()

#Add Node
Li.AddBeginning("Juni")
Li.AddBeginning("Mei")
Li.AddBeginning("April")
print("List before removal")
Li.listprint()
print("=====================================================================")
Li.RemoveFirst()
print("List after removal")
Li.listprint()
# Out:
# List before removal
# April
# Mei
# Juni
# =====================================================================
# List after removal
# Mei
# Juni

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None
 
class LinkedList:
    def __init__(self):
        self.headval = None

#Print the linked list
    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

#Add node in the end
    def AddinEnd(self, newdata):
        NewNode = Node(newdata)
        if self.headval is None:
            self.headval = NewNode
            return
        last = self.headval
        while(last.nextval):
            last = last.nextval
        last.nextval=NewNode

#Remove end node
    def RemoveEnd(self):
        last = self.headval
        while(last is not None):
            if last.nextval is None:
                break
            prev = last
            last = last.nextval
        if(last == None):
            return
        prev.nextval = last.nextval
        last = None

Li = LinkedList()

#Add Node
Li.AddinEnd("April")
Li.AddinEnd("Mei")
Li.AddinEnd("Juni")
print("List before removal")
Li.listprint()
print("=====================================================================")
Li.RemoveEnd()
print("List after removal")
Li.listprint()
# Out:
# List before removal
# April
# Mei
# Juni
# =====================================================================
# List after removal
# April
# Mei

# %% [markdown]
# <h1>Latihan 1

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None
 
class LinkedList:
    def __init__(self):
        self.headval = None

#Print the linked list
    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

#Add node in the end
    def AddinEnd(self, newdata):
        NewNode = Node(newdata)
        if self.headval is None:
            self.headval = NewNode
            return
        last = self.headval
        while(last.nextval):
            last = last.nextval
        last.nextval=NewNode

#Add in between'
    def AddinBetween(self, mid_node, newdata):
        if mid_node is None:
            print("The mentioned node is absent")
            return
        NewNode = Node(newdata)
        NewNode.nextval = mid_node.nextval
        mid_node.nextval = NewNode

#Remove node by key
    def RemoveNode(self, Removekey):
        HeadVal = self.headval
        if (HeadVal is not None):
            if (HeadVal.dataval == Removekey):
                self.headval = HeadVal.nextval
                HeadVal = None
                return
        while (HeadVal is not None):
            if HeadVal.dataval == Removekey:
                break
            prev = HeadVal
            HeadVal = HeadVal.nextval
        if (HeadVal == None):
            return
        prev.nextval = HeadVal.nextval
        HeadVal = None

Li = LinkedList()

#Add Node
Li.AddinEnd("April")
Li.AddinEnd("Mei")
Li.AddinEnd("Juli")
print("List before manipulation")
Li.listprint()
print("=====================================================================")
Li.AddinBetween(Li.headval.nextval,"Juni")
print("List after Add in between")
Li.listprint()
print("=====================================================================")
Li.RemoveNode("Mei")
print("List after removal")
Li.listprint()
# Out:
# List before manipulation
# April
# Mei
# Juli
# =====================================================================
# List after Add in between
# April
# Mei
# Juni
# Juli
# =====================================================================
# List after removal
# April
# Juni
# Juli

# %% [markdown]
# <h1>Latihan 2

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

class LinkedList:
    def __init__(self):
        self.headval = None

    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

#subclass linkedlist
class CircularLinkedList(LinkedList):
    def __init__(self):
        super().__init__()

#add node
    def addNode(self, newdata):
        NewNode = Node(newdata)
        if self.headval is None:
            self.headval = NewNode
            NewNode.nextval = self.headval
        else:
            temp = self.headval
            while temp.nextval != self.headval:
                temp = temp.nextval
            temp.nextval = NewNode
            NewNode.nextval = self.headval

#Print List
    def listprint(self):
        printval = self.headval
        while True:
            print(printval.dataval)
            printval = printval.nextval
            if printval == self.headval:
                break

#Add node in the end
    def AddinEnd(self, newdata):
        NewNode = Node(newdata)
        if self.headval is None:
            self.headval = NewNode
            NewNode.nextval = self.headval
        else:
            temp = self.headval
            while temp.nextval != self.headval:
                temp = temp.nextval
            temp.nextval = NewNode
            NewNode.nextval = self.headval

#Remove end node
    def RemoveEnd(self):
        if self.headval is None:
            return
        elif self.headval.nextval == self.headval:
            self.headval = None
        else:
            temp = self.headval
            while temp.nextval.nextval != self.headval:
                temp = temp.nextval
            temp.nextval = self.headval


circular_list = CircularLinkedList()
circular_list.addNode("January")
circular_list.addNode("February")
circular_list.addNode("March")
circular_list.listprint()
print("\n=====================================================================")
print("\nADD IN END\n")
circular_list.AddinEnd("April")
circular_list.listprint()
print("\n=====================================================================")
print("\nREMOVE END\n")
circular_list.RemoveEnd()
circular_list.listprint()
# Out:
# January
# February
# March
#
# =====================================================================
#
# ADD IN END
#
# January
# February
# March
# April
#
# =====================================================================
#
# REMOVE END
#
# January
# February
# March
